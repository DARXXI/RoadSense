# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Запуск сегментации дорог
# ----> 2 from geodeep import predict
#       4 # Модель roads доступна из коробки
#       5 result = predict(
#       6     model="roads",
#       7     input_path="satellite_image.tif",
#       8     output_path="roads_mask.shp"
#       9 )
#
# ModuleNotFoundError: No module named 'geodeep'
